# %%
import geopandas as gpd
from mapreader import SheetDownloader

# %%
parks = gpd.read_file("./data/National_Parks_England_4829975525583709119.geojson")
south_downs = parks[parks["NAME"] == "SOUTH DOWNS"]

# %%
south_downs.head()
# Out:
#    OBJECTID  CODE         NAME  MEASURE                     DESIG_DATE  \
# 7         8    10  SOUTH DOWNS     1653  Wed, 31 Mar 2010 00:00:00 GMT
#
#                      HOTLINK      STATUS  \
# 7  http://southdowns.gov.uk/  Designated
#
#                                             geometry
# 7  POLYGON ((-0.79782 50.86568, -0.79784 50.86571...

# %%
# 1949-72

my_ts_1949_1972 = SheetDownloader(
    metadata_path="./data/api.geojson",
    download_url="https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/{z}/{x}/{y}.png"
)

# Filter metadata up to 1972
my_ts_1949_1972.extract_published_dates()
my_ts_1949_1972.metadata = my_ts_1949_1972.metadata[my_ts_1949_1972.metadata["published_date"] <= 1972]

# Query and download
my_ts_1949_1972.get_grid_bb(16)
my_ts_1949_1972.query_map_sheets_by_polygon(south_downs.iloc[0].geometry, mode="intersects")
my_ts_1949_1972.download_map_sheets_by_queries(
    force=True, download_in_parallel=False, path_save="maps_south_downs_1949_1972"
)
# Out:
# [INFO] Metadata file has 9681 item(s).
# [WARNING] Estimated total size: 1.05GB.
# 0it [00:00, ?it/s]
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244470.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244491.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244530.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244791.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244782.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244809.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244827.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244818.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244845.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244836.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244878.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189244866.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245130.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245124.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245148.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245136.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245160.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245154.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245172.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245166.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245184.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245202.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245196.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245439.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245430.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245469.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245460.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245487.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245478.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245502.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245493.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245523.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245514.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245541.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245535.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245553.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245547.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245583.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245802.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245790.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245838.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245832.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245850.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245844.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245862.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245856.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245874.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245868.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245883.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245901.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245895.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189245934.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246189.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246180.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246222.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246216.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246234.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246228.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246246.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246240.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246258.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246252.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246285.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189246279.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258152.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258146.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258173.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258185.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258179.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258197.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258191.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258203.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258221.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258215.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258509.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258500.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32687/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32688/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32689/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32690/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32691/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32692/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32693/22001.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32694/22001.png not found.
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258524.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258566.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258557.png"
#   0%|          | 0/225 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258920.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258908.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258935.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258926.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258947.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189258941.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259328.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259316.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259349.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259340.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259364.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259358.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259376.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259370.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259790.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259781.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259811.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259802.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259847.png"
#   0%|          | 0/225 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189259838.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189260192.png"
#   0%|          | 0/225 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189260213.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189260207.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32777/22016.png not found.
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189262559.png"
#   0%|          | 0/210 [00:00<?, ?it/s]
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32803/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32804/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32805/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32806/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32807/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32808/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32809/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32810/22017.png not found.
# [WARNING] https://geo.nls.uk/mapdata3/os/britain10knationalgridnew/16/32811/22017.png not found.
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189262583.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189262574.png"
#   0%|          | 0/196 [00:00<?, ?it/s]
# [INFO] Downloaded "maps_south_downs_1949_1972/map_189262589.png"

# %%
# 1973

my_ts_1973 = SheetDownloader(
    metadata_path="./data/api.geojson",  # Assuming same metadata but filtered
    download_url="https://geo.nls.uk/mapdata2/os/10k_1973/{z}/{x}/{y}.png"  # Not sure this is correct I'm guessing
)

# Filter metadata for 1973
my_ts_1973.extract_published_dates()
my_ts_1973.metadata = my_ts_1973.metadata[my_ts_1973.metadata["published_date"] == 1973]

# Query and download
my_ts_1973.get_grid_bb(16)
my_ts_1973.query_map_sheets_by_polygon(south_downs.iloc[0].geometry, mode="intersects")
my_ts_1973.download_map_sheets_by_queries(
    force=True, download_in_parallel=False, path_save="maps_south_downs_1973"
)
# Out:
# [INFO] Metadata file has 9681 item(s).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 14
#      12 # Query and download
#      13 my_ts_1973.get_grid_bb(16)
# ---> 14 my_ts_1973.query_map_sheets_by_polygon(south_downs.iloc[0].geometry, mode="intersects")
#      15 my_ts_1973.download_map_sheets_by_queries(
#      16     force=True, download_in_parallel=False, path_save="maps_south_downs_1973"
#      17 )
#
# File ~/Documents/GitHub/MapReader/mapreader/download/sheet_downloader.py:272, in SheetDownloader.query_map_sheets_by_polygon(self, polygon, mode, append, print)
#     269     self.get_merged_polygon()
#     271 if self.merged_polygon.disjoint(polygon):
# --> 272     raise ValueError("[ERROR] Polygon is out of map metadata bounds.")
#     274 if mode not in ["within", "intersects"]:
#     275     raise NotImplementedError(
#     276         '[ERROR] Please use ``mode="within"`` or ``mode="intersects"``.'
#     277     )
#
# ValueError: [ERROR] Polygon is out of map metadata bounds.

# %%
# 1974

my_ts_1974 = SheetDownloader(
    metadata_path="./data/api.geojson",
    download_url="https://geo.nls.uk/mapdata3/os/10k_1974/{z}/{x}/{y}.png"
)

# Filter metadata for 1974
my_ts_1974.extract_published_dates()
my_ts_1974.metadata = my_ts_1974.metadata[my_ts_1974.metadata["published_date"] == 1974]

# Query and download
my_ts_1974.get_grid_bb(16)
my_ts_1974.query_map_sheets_by_polygon(south_downs.iloc[0].geometry, mode="intersects")
my_ts_1974.download_map_sheets_by_queries(
    force=True, download_in_parallel=False, path_save="maps_south_downs_1974"
)
# Out:
# [INFO] Metadata file has 9681 item(s).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Query and download
#      13 my_ts_1974.get_grid_bb(16)
# ---> 14 my_ts_1974.query_map_sheets_by_polygon(south_downs.iloc[0].geometry, mode="intersects")
#      15 my_ts_1974.download_map_sheets_by_queries(
#      16     force=True, download_in_parallel=False, path_save="maps_south_downs_1974"
#      17 )
#
# File ~/Documents/GitHub/MapReader/mapreader/download/sheet_downloader.py:271, in SheetDownloader.query_map_sheets_by_polygon(self, polygon, mode, append, print)
#     268 if self.merged_polygon is None:
#     269     self.get_merged_polygon()
# --> 271 if self.merged_polygon.disjoint(polygon):
#     272     raise ValueError("[ERROR] Polygon is out of map metadata bounds.")
#     274 if mode not in ["within", "intersects"]:
#
# AttributeError: 'NoneType' object has no attribute 'disjoint'
